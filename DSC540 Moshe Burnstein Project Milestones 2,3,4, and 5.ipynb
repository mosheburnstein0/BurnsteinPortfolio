# %% [markdown]
# #  Milestone 2

# %% [markdown]
# #  Cleaning, Formatting Flat File Source

# %%
54/869
# Out:
# 0.06214039125431531

# %%
import pandas as pd
import numpy as np
import os
# os.chdir('Downloads')

# %%
np_complete = pd.read_csv('complete.csv')
pd.set_option('display.max_columns', None)
np_complete.head()
# Out:
#    awardYear           category  \
# 0       2001  Economic Sciences
# 1       1975            Physics
# 2       2004          Chemistry
# 3       1982          Chemistry
# 4       1979            Physics
#
#                                     categoryFullName  sortOrder portion  \
# 0  The Sveriges Riksbank Prize in Economic Scienc...          2     1/3
# 1                         The Nobel Prize in Physics          1     1/3
# 2                       The Nobel Prize in Chemistry          1     1/3
# 3                       The Nobel Prize in Chemistry          1       1
# 4                         The Nobel Prize in Physics          2     1/3
#
#    prizeAmount  prizeAmountAdjusted dateAwarded prizeStatus  \
# 0     10000000             12295082  2001-10-10    received
# 1       630000              3404179  1975-10-17    received
# 2     10000000             11762861  2004-10-06    received
# 3      1150000              3102518  1982-10-18    received
# ...

# %%
np_complete.shape
# Out:
# (950, 52)

# %%
np_complete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 52 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   awardYear                   950 non-null    int64
#  1   category                    950 non-null    object
#  2   categoryFullName            950 non-null    object
#  3   sortOrder                   950 non-null    int64
#  4   portion                     950 non-null    object
#  5   prizeAmount                 950 non-null    int64
#  6   prizeAmountAdjusted         950 non-null    int64
#  7   dateAwarded                 533 non-null    object
#  8   prizeStatus                 950 non-null    object
#  9   motivation                  950 non-null    object
#  10  categoryTopMotivation       20 non-null     object
#  11  award_link                  950 non-null    object
#  12  id                          950 non-null    int64
# ...

# %%
np_complete.isnull().sum()
# Out:
# awardYear                       0
# category                        0
# categoryFullName                0
# sortOrder                       0
# portion                         0
# prizeAmount                     0
# prizeAmountAdjusted             0
# dateAwarded                   417
# prizeStatus                     0
# motivation                      0
# categoryTopMotivation         930
# award_link                      0
# id                              0
# name                            0
# knownName                      27
# givenName                      27
# familyName                     29
# fullName                       27
# penName                       939
# gender                         27
# laureate_link                   0
# birth_date                     27
# birth_city                     28
# birth_cityNow                  28
# birth_continent                27
# birth_country                  27
# birth_countryNow               27
# ...

# %%
np_complete.columns
# Out:
# Index(['awardYear', 'category', 'categoryFullName', 'sortOrder', 'portion',
#        'prizeAmount', 'prizeAmountAdjusted', 'dateAwarded', 'prizeStatus',
#        'motivation', 'categoryTopMotivation', 'award_link', 'id', 'name',
#        'knownName', 'givenName', 'familyName', 'fullName', 'penName', 'gender',
#        'laureate_link', 'birth_date', 'birth_city', 'birth_cityNow',
#        'birth_continent', 'birth_country', 'birth_countryNow',
#        'birth_locationString', 'death_date', 'death_city', 'death_cityNow',
#        'death_continent', 'death_country', 'death_countryNow',
#        'death_locationString', 'orgName', 'nativeName', 'acronym',
#        'org_founded_date', 'org_founded_city', 'org_founded_cityNow',
#        'org_founded_continent', 'org_founded_country',
#        'org_founded_countryNow', 'org_founded_locationString', 'ind_or_org',
#        'residence_1', 'residence_2', 'affiliation_1', 'affiliation_2',
#        'affiliation_3', 'affiliation_4'],
# ...

# %% [markdown]
# #  Step 1: Remove many columns with null values, and keep necessary columns. This will solve a large part of the null value problem so present in the df. Keep columns that may be necessary for the EDA, and decide on a case by case basis how to deal with the NaNs.

# %%
new_flat_df = np_complete[['awardYear', 'category', 'categoryFullName', 'portion','prizeAmount', 'prizeAmountAdjusted',\
                           'dateAwarded', 'name', 'knownName', 'givenName', 'familyName',  'gender', 'birth_date',\
                          'death_date']]
new_flat_df
# Out:
#      awardYear           category  \
# 0         2001  Economic Sciences
# 1         1975            Physics
# 2         2004          Chemistry
# 3         1982          Chemistry
# 4         1979            Physics
# ..         ...                ...
# 945       1972            Physics
# 946       1954          Chemistry
# 947       1911          Chemistry
# 948       1981              Peace
# 949       1963              Peace
#
#                                       categoryFullName portion  prizeAmount  \
# 0    The Sveriges Riksbank Prize in Economic Scienc...     1/3     10000000
# 1                           The Nobel Prize in Physics     1/3       630000
# 2                         The Nobel Prize in Chemistry     1/3     10000000
# 3                         The Nobel Prize in Chemistry       1      1150000
# 4                           The Nobel Prize in Physics     1/3       800000
# ..                                                 ...     ...          ...
# ...

# %%
new_flat_df.isnull().sum()
# Out:
# awardYear                0
# category                 0
# categoryFullName         0
# portion                  0
# prizeAmount              0
# prizeAmountAdjusted      0
# dateAwarded            417
# name                     0
# knownName               27
# givenName               27
# familyName              29
# gender                  27
# birth_date              27
# death_date             320
# dtype: int64

# %%
new_flat_df.dtypes
# Out:
# awardYear               int64
# category               object
# categoryFullName       object
# portion                object
# prizeAmount             int64
# prizeAmountAdjusted     int64
# dateAwarded            object
# name                   object
# knownName              object
# givenName              object
# familyName             object
# gender                 object
# birth_date             object
# death_date             object
# dtype: object

# %% [markdown]
# # Step 2: These three date columns are object strings. Use datetime to convert them to datetime objects and enable to work with as dates.

# %%
new_flat_df[['dateAwarded', 'birth_date', 'death_date']] = new_flat_df[['dateAwarded', 'birth_date', 'death_date']]\
            .apply(pd.to_datetime, errors='coerce')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14880\3613623049.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_flat_df[['dateAwarded', 'birth_date', 'death_date']] = new_flat_df[['dateAwarded', 'birth_date', 'death_date']]\

# %%
new_flat_df[['dateAwarded', 'birth_date', 'death_date']]
# Out:
#     dateAwarded birth_date death_date
# 0    2001-10-10        NaT        NaT
# 1    1975-10-17 1922-06-19 2009-09-08
# 2    2004-10-06 1947-10-01        NaT
# 3    1982-10-18 1926-08-11 2018-11-20
# 4    1979-10-15 1926-01-29 1996-11-21
# ..          ...        ...        ...
# 945         NaT 1908-05-23 1991-01-30
# 946         NaT 1901-02-28 1994-08-19
# 947         NaT 1867-11-07 1934-07-04
# 948  1981-10-14        NaT        NaT
# 949  1963-10-10        NaT        NaT
#
# [950 rows x 3 columns]

# %%
new_flat_df.dtypes
# Out:
# awardYear                       int64
# category                       object
# categoryFullName               object
# portion                        object
# prizeAmount                     int64
# prizeAmountAdjusted             int64
# dateAwarded            datetime64[ns]
# name                           object
# knownName                      object
# givenName                      object
# familyName                     object
# gender                         object
# birth_date             datetime64[ns]
# death_date             datetime64[ns]
# dtype: object

# %%
new_flat_df.isnull().sum()
# Out:
# awardYear                0
# category                 0
# categoryFullName         0
# portion                  0
# prizeAmount              0
# prizeAmountAdjusted      0
# dateAwarded            417
# name                     0
# knownName               27
# givenName               27
# familyName              29
# gender                  27
# birth_date              33
# death_date             320
# dtype: int64

# %% [markdown]
# #  Explore different groupings.

# %%
new_flat_df['portion'].unique()
# Out:
# array(['1/3', '1', '1/4', '1/2'], dtype=object)

# %%
new_flat_df['category'].unique()
# Out:
# array(['Economic Sciences', 'Physics', 'Chemistry', 'Peace',
#        'Physiology or Medicine', 'Literature'], dtype=object)

# %%
new_flat_df['categoryFullName'].unique()
# Out:
# array(['The Sveriges Riksbank Prize in Economic Sciences in Memory of Alfred Nobel',
#        'The Nobel Prize in Physics', 'The Nobel Prize in Chemistry',
#        'The Nobel Peace Prize',
#        'The Nobel Prize in Physiology or Medicine',
#        'The Nobel Prize in  Literature'], dtype=object)

# %%
new_flat_df['prizeAmountAdjusted'].describe()
# Out:
# count    9.500000e+02
# mean     6.145681e+06
# std      3.276874e+06
# min      2.377268e+06
# 25%      3.052326e+06
# 50%      4.997406e+06
# 75%      9.044276e+06
# max      1.229508e+07
# Name: prizeAmountAdjusted, dtype: float64

# %%
new_flat_df['prizeAmountAdjusted'].mean()
# Out:
# 6145680.669473684

# %%
new_flat_df['birth_date'].sort_values()
# Out:
# 850   1817-11-30
# 260   1822-05-20
# 705   1828-03-18
# 360   1828-05-08
# 78    1829-07-26
#          ...
# 877          NaT
# 880          NaT
# 944          NaT
# 948          NaT
# 949          NaT
# Name: birth_date, Length: 950, dtype: datetime64[ns]

# %%
new_flat_df['birth_date'].describe()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14880\2148452641.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   new_flat_df['birth_date'].describe()
# count                     917
# unique                    900
# top       1941-05-31 00:00:00
# freq                        2
# first     1817-11-30 00:00:00
# last      1997-07-12 00:00:00
# Name: birth_date, dtype: object

# %%
new_flat_df['birth_date'].describe(datetime_is_numeric=True)
# Out:
# count                              917
# mean     1911-07-16 04:09:41.025081856
# min                1817-11-30 00:00:00
# 25%                1891-10-20 00:00:00
# 50%                1917-03-24 00:00:00
# 75%                1936-03-28 00:00:00
# max                1997-07-12 00:00:00
# Name: birth_date, dtype: object

# %%
from dateutil import relativedelta

# %% [markdown]
# #  Step 3: Create column 'years_lived' to represent lifespan. Use   np.timedelta64 to compute lifespans from birth date and death date.

# %%
# Calculate lifespan
new_flat_df['years_lived'] = (new_flat_df['death_date'] - new_flat_df['birth_date']) / np.timedelta64(1, 'Y')
new_flat_df['years_lived']
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14880\212087586.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_flat_df['years_lived'] = (new_flat_df['death_date'] - new_flat_df['birth_date']) / np.timedelta64(1, 'Y')
# 0            NaN
# 1      87.224241
# 2            NaN
# 3      92.278418
# 4      70.813227
#          ...
# 945    82.690267
# 946    93.472145
# 947    66.654346
# 948          NaN
# 949          NaN
# Name: years_lived, Length: 950, dtype: float64

# %%
# Round down to lower integer to get age in years
new_flat_df['years_lived'] = new_flat_df['years_lived'].apply(np.floor)
new_flat_df['years_lived']
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14880\935813651.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_flat_df['years_lived'] = new_flat_df['years_lived'].apply(np.floor)
# 0       NaN
# 1      87.0
# 2       NaN
# 3      92.0
# 4      70.0
#        ...
# 945    82.0
# 946    93.0
# 947    66.0
# 948     NaN
# 949     NaN
# Name: years_lived, Length: 950, dtype: float64

# %%
new_flat_df
# Out:
#      awardYear           category  \
# 0         2001  Economic Sciences
# 1         1975            Physics
# 2         2004          Chemistry
# 3         1982          Chemistry
# 4         1979            Physics
# ..         ...                ...
# 945       1972            Physics
# 946       1954          Chemistry
# 947       1911          Chemistry
# 948       1981              Peace
# 949       1963              Peace
#
#                                       categoryFullName portion  prizeAmount  \
# 0    The Sveriges Riksbank Prize in Economic Scienc...     1/3     10000000
# 1                           The Nobel Prize in Physics     1/3       630000
# 2                         The Nobel Prize in Chemistry     1/3     10000000
# 3                         The Nobel Prize in Chemistry       1      1150000
# 4                           The Nobel Prize in Physics     1/3       800000
# ..                                                 ...     ...          ...
# ...

# %%
duplicate_Rows = new_flat_df[new_flat_df.duplicated()]
duplicate_Rows
# Out:
# Empty DataFrame
# Columns: [awardYear, category, categoryFullName, portion, prizeAmount, prizeAmountAdjusted, dateAwarded, name, knownName, givenName, familyName, gender, birth_date, death_date, years_lived]
# Index: []

# %% [markdown]
# #  Step 4: Explore different groupings for average age. Display laureates by prize category and gender. Show numbers of laureates per gender, per prize. Initiate variables to hold grouped values.

# %%
new_flat_df.groupby('gender')['years_lived'].mean()
# Out:
# gender
# female    78.392857
# male      79.948419
# Name: years_lived, dtype: float64

# %%
avg_lifespan_by_category_by_sex = new_flat_df.groupby(['categoryFullName', 'gender'])['years_lived'].mean()
avg_lifespan_by_category_by_sex
# Out:
# categoryFullName                                                            gender
# The Nobel Peace Prize                                                       female    79.571429
#                                                                             male      76.925373
# The Nobel Prize in  Literature                                              female    79.700000
#                                                                             male      78.853933
# The Nobel Prize in Chemistry                                                female    69.333333
#                                                                             male      78.848739
# The Nobel Prize in Physics                                                  female    65.500000
#                                                                             male      80.299270
# The Nobel Prize in Physiology or Medicine                                   female    84.800000
# ...

# %%
new_flat_df['gender'].value_counts()
# Out:
# male      869
# female     54
# Name: gender, dtype: int64

# %%
gendercount_by_category = new_flat_df.groupby('categoryFullName')['gender'].value_counts()
gendercount_by_category
# Out:
# categoryFullName                                                            gender
# The Nobel Peace Prize                                                       male       90
#                                                                             female     17
# The Nobel Prize in  Literature                                              male      101
#                                                                             female     15
# The Nobel Prize in Chemistry                                                male      179
#                                                                             female      5
# The Nobel Prize in Physics                                                  male      210
#                                                                             female      3
# The Nobel Prize in Physiology or Medicine                                   male      207
# ...

# %%
prize_portion_by_gender_age = new_flat_df.groupby(['categoryFullName', 'gender', 'portion'])['years_lived'].mean()
prize_portion_by_gender_age
# Out:
# categoryFullName                                                            gender  portion
# The Nobel Peace Prize                                                       female  1          76.333333
#                                                                                     1/2        82.000000
#                                                                                     1/3              NaN
#                                                                             male    1          76.272727
#                                                                                     1/2        77.290323
#                                                                                     1/3        80.333333
# The Nobel Prize in  Literature                                              female  1          79.888889
#                                                                                     1/2        78.000000
# ...

# %%
new_flat_df.groupby(['categoryFullName', 'gender'])['portion'].value_counts()
# Out:
# categoryFullName                                                            gender  portion
# The Nobel Peace Prize                                                       female  1/2         8
#                                                                                     1           6
#                                                                                     1/3         3
#                                                                             male    1          45
#                                                                                     1/2        42
#                                                                                     1/3         3
# The Nobel Prize in  Literature                                              female  1          14
#                                                                                     1/2         1
#                                                                             male    1          94
# ...

# %%
new_flat_df.groupby(['gender'])['portion'].value_counts()
# Out:
# gender  portion
# female  1           23
#         1/2         16
#         1/3          9
#         1/4          6
# male    1          310
#         1/2        290
#         1/3        207
#         1/4         62
# Name: portion, dtype: int64

# %%
new_flat_df.groupby(['gender', 'portion'])['years_lived'].mean()
# Out:
# gender  portion
# female  1          79.200000
#         1/2        81.555556
#         1/3        81.000000
#         1/4        64.000000
# male    1          77.726592
#         1/2        81.108911
#         1/3        82.849057
#         1/4        81.923077
# Name: years_lived, dtype: float64

# %%
import seaborn as sns
sns.boxplot(new_flat_df.years_lived)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='years_lived'>

# %%
import matplotlib.pyplot as plt
plt.hist(new_flat_df.years_lived, 20)
# Out:
# (array([ 1.,  1.,  4.,  2.,  3., 15., 11., 17., 36., 33., 62., 49., 60.,
#         65., 82., 82., 52., 41., 11.,  2.]),
#  array([ 39. ,  42.2,  45.4,  48.6,  51.8,  55. ,  58.2,  61.4,  64.6,
#          67.8,  71. ,  74.2,  77.4,  80.6,  83.8,  87. ,  90.2,  93.4,
#          96.6,  99.8, 103. ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# #  Step 5: Use fuzzy matching on 2 name columns

# %% [markdown]
# #  I anticipate merging on names. Will try to assess best names to use. Will get a score comparing the two strings and will make new bool column displaying close matches.

# %%
# Compare 2 of the name columns
new_flat_df['name'].tail(), new_flat_df['knownName'].tail()
# Out:
# (945                                         John Bardeen
#  946                                        Linus Pauling
#  947                                          Marie Curie
#  948    Office of the United Nations High Commissioner...
#  949             International Committee of the Red Cross
#  Name: name, dtype: object,
#  945     John Bardeen
#  946    Linus Pauling
#  947      Marie Curie
#  948              NaN
#  949              NaN
#  Name: knownName, dtype: object)

# %%
# !pip install fuzzywuzzy
# !pip install python-Levenshtein

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process, fuzz

# %%
new_flat_df['name'].isna().sum()
# Out:
# 0

# %%
new_flat_df['knownName'].isna().sum()
# Out:
# 27

# %%
# Compare columns to check for equal values
new_flat_df['name'].equals(new_flat_df['knownName'])
# Out:
# False

# %%
new_flat_df['name_matches'] = new_flat_df['name'].map(lambda x : process.extractOne(x, new_flat_df['knownName'])[1])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14880\2169242408.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_flat_df['name_matches'] = new_flat_df['name'].map(lambda x : process.extractOne(x, new_flat_df['knownName'])[1])

# %%
new_flat_df['name_matches']
# Out:
# 0      100
# 1      100
# 2      100
# 3      100
# 4      100
#       ...
# 945    100
# 946    100
# 947    100
# 948     86
# 949     86
# Name: name_matches, Length: 950, dtype: int64

# %%
type(new_flat_df['name_matches'])
# Out:
# pandas.core.series.Series

# %%
new_flat_df[['name', 'knownName', 'name_matches']]
# Out:
#                                                   name          knownName  \
# 0                                    A. Michael Spence  A. Michael Spence
# 1                                         Aage N. Bohr       Aage N. Bohr
# 2                                    Aaron Ciechanover  Aaron Ciechanover
# 3                                           Aaron Klug         Aaron Klug
# 4                                          Abdus Salam        Abdus Salam
# ..                                                 ...                ...
# 945                                       John Bardeen       John Bardeen
# 946                                      Linus Pauling      Linus Pauling
# 947                                        Marie Curie        Marie Curie
# 948  Office of the United Nations High Commissioner...                NaN
# 949           International Committee of the Red Cross                NaN
#
#      name_matches
# 0             100
# 1             100
# 2             100
# ...

# %%
new_flat_df['good_matches'] = new_flat_df['name_matches'] > 86
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14880\1507015793.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_flat_df['good_matches'] = new_flat_df['name_matches'] > 86

# %%
new_flat_df.head(10)
# Out:
#    awardYear           category  \
# 0       2001  Economic Sciences
# 1       1975            Physics
# 2       2004          Chemistry
# 3       1982          Chemistry
# 4       1979            Physics
# 5       2019  Economic Sciences
# 6       2019              Peace
# 7       2009          Chemistry
# 8       2011            Physics
# 9       1939          Chemistry
#
#                                     categoryFullName portion  prizeAmount  \
# 0  The Sveriges Riksbank Prize in Economic Scienc...     1/3     10000000
# 1                         The Nobel Prize in Physics     1/3       630000
# 2                       The Nobel Prize in Chemistry     1/3     10000000
# 3                       The Nobel Prize in Chemistry       1      1150000
# 4                         The Nobel Prize in Physics     1/3       800000
# 5  The Sveriges Riksbank Prize in Economic Scienc...     1/3      9000000
# 6                              The Nobel Peace Prize       1      9000000
# ...

# %%
flat_file_df = new_flat_df[['awardYear', 'category', 'portion', 'prizeAmountAdjusted', 'knownName', 'gender', 'years_lived']]

# %%
flat_file_df.head()
# Out:
#    awardYear           category portion  prizeAmountAdjusted  \
# 0       2001  Economic Sciences     1/3             12295082
# 1       1975            Physics     1/3              3404179
# 2       2004          Chemistry     1/3             11762861
# 3       1982          Chemistry       1              3102518
# 4       1979            Physics     1/3              2988048
#
#            knownName gender  years_lived
# 0  A. Michael Spence   male          NaN
# 1       Aage N. Bohr   male         87.0
# 2  Aaron Ciechanover   male          NaN
# 3         Aaron Klug   male         92.0
# 4        Abdus Salam   male         70.0

# %% [markdown]
# #  Ethical implications of EDA

# %% [markdown]
# #  There are several ethical implications involved in the EDA of this flat file. One must deal with thousands of nulls. Many of the 52 columns are not necessary for the analysis and therefore can be dropped, obviating the need to address those many null values in the dropped columns. I left the remaining null values intact, preferring not to impute by deciding the best metric which will not alter the model due to its inexactness. Fuzzy matching is used to compare strings which are of unequal value. One must beware of false positives. Is the gain of using Fuzzy worth the downside? I mitigate the errors by setting the score for a match to be more than 86. I anticipate merging dfs and replacing nulls with real values. One must consider outliers in age and decide if they will adversely affect any extrapolations. Most concerning, however, is the small number of female laureates. Females represent such a small proportion of winners. Can one extrapolate anything meaningful from such a small sample. This problem is exacerbated when looking at female laureates by category. On such a granular level, females can be represented by single digits.

# %% [markdown]
# #  Project: Milestone 3 Cleaning/Formatting Website Data

# %% [markdown]
# #  Wiki table of life expectancy

# %%
# Initialize variable to hold pandas read_html from a web path
wiki_page = pd.read_html('https://en.wikipedia.org/wiki/List_of_countries_by_past_life_expectancy')

# %%
# pandas creates list from pd.read_html
type(wiki_page)
# Out:
# list

# %% [markdown]
# # Inspect elements on web page and note only one table. Call first index with [0]

# %%
 table = wiki_page[0]

# %%
# In tbody there is a long list of trows...231
table.shape
# Out:
# (231, 14)

# %%
# pandas created a df from the table in wiki_page list
type(table)
# Out:
# pandas.core.frame.DataFrame

# %%
table.head()
# Out:
#   Country or subnational area  1950–1955  1955–1960  1960–1965  1965–1970  \
# 0                         NaN        NaN        NaN        NaN        NaN
# 1               Afghanistan *      28.61      31.12      33.41      35.58
# 2                   Albania *      55.26      59.31      64.85      66.24
# 3                   Algeria *      42.89      45.00      47.29      49.47
# 4                    Angola *      31.39      32.54      34.09      36.04
#
#    1970–1975  1975–1980  1980–1985  1985–1990  1990–1995  1995–2000  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1      37.83      40.39      43.56      47.70      51.74      54.17
# 2      67.69      69.70      70.61      71.98      71.73      72.95
# 3      51.48      54.93      61.57      65.85      67.20      69.14
# 4      38.05      40.00      40.89      41.48      42.22      44.73
#
#    2000–2005  2005–2010  2010–2015
# 0        NaN        NaN        NaN
# 1      56.89      60.03      62.25
# ...

# %%
table.dtypes
# Out:
# Country or subnational area     object
# 1950–1955                      float64
# 1955–1960                      float64
# 1960–1965                      float64
# 1965–1970                      float64
# 1970–1975                      float64
# 1975–1980                      float64
# 1980–1985                      float64
# 1985–1990                      float64
# 1990–1995                      float64
# 1995–2000                      float64
# 2000–2005                      float64
# 2005–2010                      float64
# 2010–2015                      float64
# dtype: object

# %%
# Visualize North America row and note the steady rise in life expectancy
table[table['Country or subnational area']=='NORTH AMERICA']
# Out:
#     Country or subnational area  1950–1955  1955–1960  1960–1965  1965–1970  \
# 202               NORTH AMERICA      68.73       69.7       70.2      70.51
#
#      1970–1975  1975–1980  1980–1985  1985–1990  1990–1995  1995–2000  \
# 202      71.56      73.34      74.51      75.08      75.85      76.68
#
#      2000–2005  2005–2010  2010–2015
# 202      77.41      78.41      79.17

# %% [markdown]
# #  Transformation 1. Assign countries to columns in order to use them as features.

# %%
table_transposed = table.T

# %%
table_transposed.shape
# Out:
# (14, 231)

# %%
type(table_transposed)
# Out:
# pandas.core.frame.DataFrame

# %%
countries = table['Country or subnational area']
countries
# Out:
# 0                        NaN
# 1              Afghanistan *
# 2                  Albania *
# 3                  Algeria *
# 4                   Angola *
#                ...
# 226    Australia/New Zealand
# 227                Polynesia
# 228                Melanesia
# 229               Micronesia
# 230                    World
# Name: Country or subnational area, Length: 231, dtype: object

# %%
table_transposed.dtypes
# Out:
# 0      object
# 1      object
# 2      object
# 3      object
# 4      object
#         ...
# 226    object
# 227    object
# 228    object
# 229    object
# 230    object
# Length: 231, dtype: object

# %%
table_transposed.describe()
# Out:
#         0              1          2          3         4    \
# count     0             14         14         14        14
# unique    0             14         14         14        14
# top     NaN  Afghanistan *  Albania *  Algeria *  Angola *
# freq    NaN              1          1          1         1
#
#                         5            6          7                    8    \
# count                    14           14         14                   14
# unique                   14           14         14                   14
# top     Antigua and Barbuda  Argentina *  Armenia *  Aruba (Netherlands)
# freq                      1            1          1                    1
#
#                 9          10            11       12         13   \
# count            14         14            14       14         14
# unique           14         14            14       14         14
# top     Australia *  Austria *  Azerbaijan *  Bahamas  Bahrain *
# ...

# %% [markdown]
# #  Transformation 2. Country or subnational area followed by year periods became the index. Remove it and leave an index of numbers starting at 0.

# %%
table_transposed.head()
# Out:
#                              0              1          2          3    \
# Country or subnational area  NaN  Afghanistan *  Albania *  Algeria *
# 1950–1955                    NaN          28.61      55.26      42.89
# 1955–1960                    NaN          31.12      59.31       45.0
# 1960–1965                    NaN          33.41      64.85      47.29
# 1965–1970                    NaN          35.58      66.24      49.47
#
#                                   4                    5            6    \
# Country or subnational area  Angola *  Antigua and Barbuda  Argentina *
# 1950–1955                       31.39                58.51        62.57
# 1955–1960                       32.54                61.03        64.58
# 1960–1965                       34.09                63.18        65.31
# 1965–1970                       36.04                65.05        65.84
#
#                                    7                    8            9    \
# ...

# %%
table_transposed.reset_index(level=0, inplace=True)

# %%
table_transposed.head()
# Out:
#                          index    0              1          2          3  \
# 0  Country or subnational area  NaN  Afghanistan *  Albania *  Algeria *
# 1                    1950–1955  NaN          28.61      55.26      42.89
# 2                    1955–1960  NaN          31.12      59.31       45.0
# 3                    1960–1965  NaN          33.41      64.85      47.29
# 4                    1965–1970  NaN          35.58      66.24      49.47
#
#           4                    5            6          7                    8  \
# 0  Angola *  Antigua and Barbuda  Argentina *  Armenia *  Aruba (Netherlands)
# 1     31.39                58.51        62.57      62.82                60.44
# 2     32.54                61.03        64.58      64.92                64.36
# 3     34.09                63.18        65.31      67.04                66.58
# 4     36.04                65.05        65.84      69.18                68.22
#
# ...

# %% [markdown]
# # Transformation 3. Set the first row as column names.

# %%
table_transposed.columns = table_transposed.iloc[0]

# %%
table_transposed.head()
# Out:
# 0  Country or subnational area  NaN  Afghanistan *  Albania *  Algeria *  \
# 0  Country or subnational area  NaN  Afghanistan *  Albania *  Algeria *
# 1                    1950–1955  NaN          28.61      55.26      42.89
# 2                    1955–1960  NaN          31.12      59.31       45.0
# 3                    1960–1965  NaN          33.41      64.85      47.29
# 4                    1965–1970  NaN          35.58      66.24      49.47
#
# 0  Angola *  Antigua and Barbuda  Argentina *  Armenia *  Aruba (Netherlands)  \
# 0  Angola *  Antigua and Barbuda  Argentina *  Armenia *  Aruba (Netherlands)
# 1     31.39                58.51        62.57      62.82                60.44
# 2     32.54                61.03        64.58      64.92                64.36
# 3     34.09                63.18        65.31      67.04                66.58
# 4     36.04                65.05        65.84      69.18                68.22
#
# ...

# %% [markdown]
# #  Remove first row

# %%
table_transposed = table_transposed[1:]

# %%
table_transposed.head()
# Out:
# 0 Country or subnational area  NaN Afghanistan * Albania * Algeria * Angola *  \
# 1                   1950–1955  NaN         28.61     55.26     42.89    31.39
# 2                   1955–1960  NaN         31.12     59.31      45.0    32.54
# 3                   1960–1965  NaN         33.41     64.85     47.29    34.09
# 4                   1965–1970  NaN         35.58     66.24     49.47    36.04
# 5                   1970–1975  NaN         37.83     67.69     51.48    38.05
#
# 0 Antigua and Barbuda Argentina * Armenia * Aruba (Netherlands) Australia *  \
# 1               58.51       62.57     62.82               60.44       69.37
# 2               61.03       64.58     64.92               64.36       70.42
# 3               63.18       65.31     67.04               66.58       70.87
# 4               65.05       65.84     69.18               68.22       70.83
# 5               66.71       67.28     70.75               70.05       71.75
#
# ...

# %%
# Reset index values
table_transposed.reset_index(drop=True, inplace=True)

# %%
table_transposed.head()
# Out:
# 0 Country or subnational area  NaN Afghanistan * Albania * Algeria * Angola *  \
# 0                   1950–1955  NaN         28.61     55.26     42.89    31.39
# 1                   1955–1960  NaN         31.12     59.31      45.0    32.54
# 2                   1960–1965  NaN         33.41     64.85     47.29    34.09
# 3                   1965–1970  NaN         35.58     66.24     49.47    36.04
# 4                   1970–1975  NaN         37.83     67.69     51.48    38.05
#
# 0 Antigua and Barbuda Argentina * Armenia * Aruba (Netherlands) Australia *  \
# 0               58.51       62.57     62.82               60.44       69.37
# 1               61.03       64.58     64.92               64.36       70.42
# 2               63.18       65.31     67.04               66.58       70.87
# 3               65.05       65.84     69.18               68.22       70.83
# 4               66.71       67.28     70.75               70.05       71.75
#
# ...

# %%
table_transposed.dtypes
# Out:
# 0
# Country or subnational area    object
# NaN                            object
# Afghanistan *                  object
# Albania *                      object
# Algeria *                      object
#                                 ...
# Australia/New Zealand          object
# Polynesia                      object
# Melanesia                      object
# Micronesia                     object
# World                          object
# Length: 232, dtype: object

# %%
table_transposed.describe()
# Out:
# 0      Country or subnational area  NaN  Afghanistan *  Albania *  Algeria *  \
# count                           13    0          13.00      13.00      13.00
# unique                          13    0          13.00      13.00      13.00
# top                      1950–1955  NaN          28.61      55.26      42.89
# freq                             1  NaN           1.00       1.00       1.00
#
# 0       Angola *  Antigua and Barbuda  Argentina *  Armenia *  \
# count      13.00                13.00        13.00      13.00
# unique     13.00                13.00        13.00      13.00
# top        31.39                58.51        62.57      62.82
# freq        1.00                 1.00         1.00       1.00
#
# 0       Aruba (Netherlands)  Australia *  Austria *  Azerbaijan *  Bahamas  \
# count                 13.00        13.00      13.00         13.00    13.00
# unique                13.00        13.00      13.00         13.00    13.00
# ...

# %% [markdown]
# # Columns are all objects. Check for nulls which may preclude converting columns to floats.

# %%
table_transposed.isnull()
# Out:
# 0   Country or subnational area   NaN  Afghanistan *  Albania *  Algeria *  \
# 0                         False  True          False      False      False
# 1                         False  True          False      False      False
# 2                         False  True          False      False      False
# 3                         False  True          False      False      False
# 4                         False  True          False      False      False
# 5                         False  True          False      False      False
# 6                         False  True          False      False      False
# 7                         False  True          False      False      False
# 8                         False  True          False      False      False
# 9                         False  True          False      False      False
# 10                        False  True          False      False      False
# ...

# %%
table_transposed.isnull().sum()
# Out:
# 0
# Country or subnational area     0
# NaN                            13
# Afghanistan *                   0
# Albania *                       0
# Algeria *                       0
#                                ..
# Australia/New Zealand           0
# Polynesia                       0
# Melanesia                       0
# Micronesia                      0
# World                           0
# Length: 232, dtype: int64

# %% [markdown]
# #  Transformation 4. Remove 'NaN' column and convert df to floats.

# %%
table_transposed = table_transposed.dropna(axis=1)
table_transposed
# Out:
# 0  Country or subnational area Afghanistan * Albania * Algeria * Angola *  \
# 0                    1950–1955         28.61     55.26     42.89    31.39
# 1                    1955–1960         31.12     59.31      45.0    32.54
# 2                    1960–1965         33.41     64.85     47.29    34.09
# 3                    1965–1970         35.58     66.24     49.47    36.04
# 4                    1970–1975         37.83     67.69     51.48    38.05
# 5                    1975–1980         40.39      69.7     54.93     40.0
# 6                    1980–1985         43.56     70.61     61.57    40.89
# 7                    1985–1990          47.7     71.98     65.85    41.48
# 8                    1990–1995         51.74     71.73      67.2    42.22
# 9                    1995–2000         54.17     72.95     69.14    44.73
# 10                   2000–2005         56.89     74.83      71.5    49.98
# 11                   2005–2010         60.03     75.65     73.88    55.59
# ...

# %%
table_transposed.isnull().sum()
# Out:
# 0
# Country or subnational area    0
# Afghanistan *                  0
# Albania *                      0
# Algeria *                      0
# Angola *                       0
#                               ..
# Australia/New Zealand          0
# Polynesia                      0
# Melanesia                      0
# Micronesia                     0
# World                          0
# Length: 231, dtype: int64

# %%
table_transposed.columns
# Out:
# Index(['Country or subnational area', 'Afghanistan *', 'Albania *',
#        'Algeria *', 'Angola *', 'Antigua and Barbuda', 'Argentina *',
#        'Armenia *', 'Aruba (Netherlands)', 'Australia *',
#        ...
#        'Central Asia', 'Southern Asia', 'Eastern Asia', 'Southeast Asia',
#        'OCEANIA', 'Australia/New Zealand', 'Polynesia', 'Melanesia',
#        'Micronesia', 'World'],
#       dtype='object', name=0, length=231)

# %%
# Rename 'Country or subnational area' column
table_transposed.rename(columns = {'Country or subnational area':'Time Periods'}, inplace = True)

# %%
table_transposed.head()
# Out:
# 0 Time Periods Afghanistan * Albania * Algeria * Angola * Antigua and Barbuda  \
# 0    1950–1955         28.61     55.26     42.89    31.39               58.51
# 1    1955–1960         31.12     59.31      45.0    32.54               61.03
# 2    1960–1965         33.41     64.85     47.29    34.09               63.18
# 3    1965–1970         35.58     66.24     49.47    36.04               65.05
# 4    1970–1975         37.83     67.69     51.48    38.05               66.71
#
# 0 Argentina * Armenia * Aruba (Netherlands) Australia * Austria *  \
# 0       62.57     62.82               60.44       69.37     66.54
# 1       64.58     64.92               64.36       70.42     68.02
# 2       65.31     67.04               66.58       70.87     69.66
# 3       65.84     69.18               68.22       70.83     70.14
# 4       67.28     70.75               70.05       71.75      70.8
#
# 0 Azerbaijan * Bahamas Bahrain * Bangladesh * Barbados * Belarus * Belgium *  \
# ...

# %% [markdown]
# #  Transformation 5 Convert several df columns to floats

# %%
table_transposed.dtypes
# Out:
# 0
# Time Periods             object
# Afghanistan *            object
# Albania *                object
# Algeria *                object
# Angola *                 object
#                           ...
# Australia/New Zealand    object
# Polynesia                object
# Melanesia                object
# Micronesia               object
# World                    object
# Length: 231, dtype: object

# %%
table_transposed = table_transposed.astype(float, errors='ignore')

# %%
list(table_transposed)
# Out:
# ['Time Periods',
#  'Afghanistan\u202f*',
#  'Albania\u202f*',
#  'Algeria\u202f*',
#  'Angola\u202f*',
#  'Antigua and Barbuda',
#  'Argentina\u202f*',
#  'Armenia\u202f*',
#  'Aruba (Netherlands)',
#  'Australia\u202f*',
#  'Austria\u202f*',
#  'Azerbaijan\u202f*',
#  'Bahamas',
#  'Bahrain\u202f*',
#  'Bangladesh\u202f*',
#  'Barbados\u202f*',
#  'Belarus\u202f*',
#  'Belgium\u202f*',
#  'Belize\u202f*',
#  'Benin\u202f*',
#  'Bhutan\u202f*',
#  'Bolivia\u202f*',
#  'Bosnia and Herzegovina\u202f*',
#  'Botswana\u202f*',
#  'Brazil\u202f*',
#  'Brunei\u202f*',
#  'Bulgaria\u202f*',
#  'Burkina Faso\u202f*',
#  'Burundi\u202f*',
#  'Cambodia\u202f*',
#  'Cameroon\u202f*',
#  'Canada\u202f*',
#  'Cape Verde\u202f*',
#  'Central African Republic\u202f*',
#  'Chad\u202f*',
#  'Guernsey and Jersey\u202f* (UK)',
#  'Chile\u202f*',
#  'China\u202f*',
#  'Colombia\u202f*',
#  'Comoros\u202f*',
#  'Costa Rica\u202f*',
#  'Croatia\u202f*',
#  'Cuba\u202f*',
# ...

# %%
table_transposed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Columns: 231 entries, Time Periods to World
# dtypes: object(231)
# memory usage: 23.6+ KB

# %%
table_transposed['Afghanistan *'] = table_transposed['Afghanistan *'].astype(float)

# %%
table_transposed.dtypes
# Out:
# 0
# Time Periods              object
# Afghanistan *            float64
# Albania *                 object
# Algeria *                 object
# Angola *                  object
#                           ...
# Australia/New Zealand     object
# Polynesia                 object
# Melanesia                 object
# Micronesia                object
# World                     object
# Length: 231, dtype: object

# %%
table_transposed['NORTH AMERICA'] = table_transposed['NORTH AMERICA'].astype(float)

# %%
table_transposed['NORTH AMERICA'].dtype
# Out:
# dtype('float64')

# %%
avg_lifespan_North_America = table_transposed['NORTH AMERICA'].mean()
avg_lifespan_North_America
# Out:
# 73.93461538461538

# %%
table_transposed['NORTH AMERICA'].describe()
# Out:
# count    13.000000
# mean     73.934615
# std       3.524357
# min      68.730000
# 25%      70.510000
# 50%      74.510000
# 75%      76.680000
# max      79.170000
# Name: NORTH AMERICA, dtype: float64

# %%
first_time_period = table_transposed['NORTH AMERICA'].iloc[0]
first_time_period
# Out:
# 68.73

# %%
table_transposed['United Kingdom\u202f*'].describe()
# Out:
# count     13.0
# unique    13.0
# top       69.4
# freq       1.0
# Name: United Kingdom *, dtype: float64

# %%
table_transposed['United Kingdom\u202f*'] = table_transposed['United Kingdom\u202f*'].astype(float)

# %%
avg_lifespan_UK = table_transposed['United Kingdom\u202f*'].mean()
avg_lifespan_UK
# Out:
# 74.60076923076923

# %%
table_transposed['France\u202f*'] = table_transposed['France\u202f*'].astype(float)

# %%
first_period_France = table_transposed['France\u202f*'].iloc[0]
first_period_France
# Out:
# 67.05

# %%
avg_lifespan_France = table_transposed['France\u202f*'].mean()
avg_lifespan_France
# Out:
# 74.78999999999999

# %%
table_transposed['United Kingdom\u202f*'].describe()
# Out:
# count    13.000000
# mean     74.600769
# std       3.688779
# min      69.400000
# 25%      71.710000
# 50%      74.200000
# 75%      77.180000
# max      80.970000
# Name: United Kingdom *, dtype: float64

# %%
first_period_UK = table_transposed['United Kingdom\u202f*'].iloc[0]
first_period_UK
# Out:
# 69.4

# %%
first_period_US = table_transposed['United States\u202f*'].iloc[0]
first_period_US
# Out:
# 68.71

# %%
table_transposed['United States\u202f*'].describe()
# Out:
# count     13.00
# unique    13.00
# top       68.71
# freq       1.00
# Name: United States *, dtype: float64

# %%
table_transposed['United States\u202f*'] = table_transposed['United States\u202f*'].astype(float)

# %%
avg_lifespan_US = table_transposed['United States\u202f*'].mean()
avg_lifespan_US
# Out:
# 73.78307692307693

# %%
table_transposed['United States\u202f*'].describe()
# Out:
# count    13.000000
# mean     73.783077
# std       3.450904
# min      68.710000
# 25%      70.370000
# 50%      74.380000
# 75%      76.490000
# max      78.880000
# Name: United States *, dtype: float64

# %% [markdown]
# #  Ethical Implications... The table in this study comes from Wikipedia, whose entries are user-generated and potentially user-manipulated. Although studies have shown Wikipedia to be only as mistake-prone and inaccurate as other information sources, it would be appropriate to independently verify the results culled from such a page. Life expectancy entries per five-year time period are estimates of how long a person born during that period would live on average, were mortality rates to remain constant. These are perforce only estimates because mortality rates change over time. Therefore we should not expect that a baby born today will actually live the amount of years suggested by a table. The table does not account for life expectancy differences across genders. It is well documented how females live longer than males, and the reasons are many. We have yet to have a full understanding as to what drives the different mortality rates. We do not have demographics of the laureates and we do not know how the Wikipedia page's table was taken from a sample. Do the laureates have better access to healthcare than a sample representative of a country at large?

# %%
table_transposed.shape
# Out:
# (13, 231)

# %%
table_transposed_df = pd.concat([table_transposed, new_flat_df['knownName']], ignore_index=False, axis=1)

# %%
table_transposed_df.shape
# Out:
# (950, 232)

# %%
# Create 'avg_lifespan_1950' column from average lifespan in U.S. in 1950-1955
table_transposed_df['avg_lifespan_1950'] = first_period_US

# %%
table_transposed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 950 entries, 0 to 949
# Columns: 233 entries, Time Periods to avg_lifespan_1950
# dtypes: float64(6), object(227)
# memory usage: 1.7+ MB

# %% [markdown]
# #  Project: Milestone 4 Connecting to an API/Pulling in the Data and Cleaning/Formatting

# %%
# Use requests library to connect to API and access information
import pandas as pd
import requests

url = "http://api.nobelprize.org/v1/laureate.json?gender=All"

headers = {"accept": "application/json"}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"laureates":[{"id":"1","firstname":"Wilhelm Conrad","surname":"R\u00f6ntgen","born":"1845-03-27","died":"1923-02-10","bornCountry":"Prussia (now Germany)","bornCountryCode":"DE","bornCity":"Lennep (now Remscheid)","diedCountry":"Germany","diedCountryCode":"DE","diedCity":"Munich","gender":"male","prizes":[{"year":"1901","category":"physics","share":"1","motivation":"\"in recognition of the extraordinary services he has rendered by the discovery of the remarkable rays subsequently named after him\"","affiliations":[{"name":"Munich University","city":"Munich","country":"Germany"}]}]},{"id":"2","firstname":"Hendrik A.","surname":"Lorentz","born":"1853-07-18","died":"1928-02-04","bornCountry":"the Netherlands","bornCountryCode":"NL","bornCity":"Arnhem","diedCountry":"the Netherlands","diedCountryCode":"NL","gender":"male","prizes":[{"year":"1902","category":"physics","share":"2","motivation":"\"in recognition of the extraordinary service they rendered by their researches into the influe
# ...

# %%
# Type of data accessed
type(response)
# Out:
# requests.models.Response

# %%
# Create dict to hold data
jsondata = response.json()

# %%
len(jsondata), type(jsondata)
# Out:
# (1, dict)

# %%
type(jsondata['laureates'][0])
# Out:
# dict

# %%
api_nobel_df = pd.DataFrame(jsondata['laureates'])

# %%
api_nobel_df.tail(10)
# Out:
#        id                   firstname      surname        born        died  \
# 971  1014                       Anton    Zeilinger  1945-05-20  0000-00-00
# 972  1015                     Carolyn     Bertozzi  1966-10-10  0000-00-00
# 973  1016                      Morten       Meldal  1954-00-00  0000-00-00
# 974  1017                       Annie       Ernaux  1940-09-01  0000-00-00
# 975  1018                        Ales  Bialiatski   1962-09-25  0000-00-00
# 976  1019                    Memorial          NaN  1987-00-00  0000-00-00
# 977  1020  Center for Civil Liberties          NaN  2007-00-00  0000-00-00
# 978  1021                         Ben     Bernanke  1953-12-13  0000-00-00
# 979  1022                     Douglas      Diamond  1953-10-25  0000-00-00
# 980  1023                      Philip       Dybvig  1955-05-22  0000-00-00
#
#     bornCountry bornCountryCode             bornCity diedCountry  \
# 971     Austria              AT     Ried im Innkreis         NaN
# ...

# %%
api_nobel_df.shape
# Out:
# (981, 13)

# %%
api_nobel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 981 entries, 0 to 980
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               981 non-null    object
#  1   firstname        980 non-null    object
#  2   surname          951 non-null    object
#  3   born             980 non-null    object
#  4   died             981 non-null    object
#  5   bornCountry      953 non-null    object
#  6   bornCountryCode  953 non-null    object
#  7   bornCity         951 non-null    object
#  8   diedCountry      641 non-null    object
#  9   diedCountryCode  641 non-null    object
#  10  diedCity         635 non-null    object
#  11  gender           981 non-null    object
#  12  prizes           981 non-null    object
# dtypes: object(13)
# memory usage: 99.8+ KB

# %%
api_nobel_df['gender'].value_counts()
# Out:
# male      894
# female     60
# org        27
# Name: gender, dtype: int64

# %%
api_nobel_df['gender'].unique()
# Out:
# array(['male', 'female', 'org'], dtype=object)

# %%
org_df = api_nobel_df[api_nobel_df['gender'] == 'org']

# %%
org_df.shape
# Out:
# (27, 13)

# %% [markdown]
# # Transformation 1: Create new column 'name' to hold entire name. Execute this by concatenating 'firstname' and 'surname'.

# %%
api_nobel_df['knownName'] = api_nobel_df['firstname'].str.cat(api_nobel_df['surname'], sep =" ")
api_nobel_df['knownName']
# Out:
# 0      Wilhelm Conrad Röntgen
# 1          Hendrik A. Lorentz
# 2               Pieter Zeeman
# 3             Henri Becquerel
# 4                Pierre Curie
#                 ...
# 976                       NaN
# 977                       NaN
# 978              Ben Bernanke
# 979           Douglas Diamond
# 980             Philip Dybvig
# Name: knownName, Length: 981, dtype: object

# %%
api_nobel_df['knownName'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 981 entries, 0 to 980
# Series name: knownName
# Non-Null Count  Dtype
# --------------  -----
# 951 non-null    object
# dtypes: object(1)
# memory usage: 7.8+ KB

# %%
api_nobel_df['knownName'].isnull().sum()
# Out:
# 30

# %% [markdown]
# #  Transformation 2: Create smaller df of female laureates.

# %%
female_df = api_nobel_df.groupby('gender')
female_df = female_df.get_group(('female'))
female_df.head()
# Out:
#       id         firstname         surname        born        died  \
# 5      6             Marie           Curie  1867-11-07  1934-07-04
# 77    79             Maria  Goeppert Mayer  1906-06-28  1972-02-20
# 189  194             Irène    Joliot-Curie  1897-09-12  1956-03-17
# 225  230  Dorothy Crowfoot         Hodgkin  1910-05-12  1994-07-29
# 338  344             Gerty            Cori  1896-08-15  1957-10-26
#
#                               bornCountry bornCountryCode  \
# 5             Russian Empire (now Poland)              PL
# 77                   Germany (now Poland)              PL
# 189                                France              FR
# 225                                 Egypt              EG
# 338  Austria-Hungary (now Czech Republic)              CZ
#
#                      bornCity     diedCountry diedCountryCode  \
# 5                      Warsaw          France              FR
# 77   Kattowitz (now Katowice)             USA              US
# ...

# %%
female_df.isnull().sum()
# Out:
# id                  0
# firstname           0
# surname             1
# born                0
# died                0
# bornCountry         0
# bornCountryCode     0
# bornCity            0
# diedCountry        33
# diedCountryCode    33
# diedCity           33
# gender              0
# prizes              0
# knownName           1
# dtype: int64

# %%
female_df.shape
# Out:
# (60, 14)

# %%
female_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 5 to 974
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               60 non-null     object
#  1   firstname        60 non-null     object
#  2   surname          59 non-null     object
#  3   born             60 non-null     object
#  4   died             60 non-null     object
#  5   bornCountry      60 non-null     object
#  6   bornCountryCode  60 non-null     object
#  7   bornCity         60 non-null     object
#  8   diedCountry      27 non-null     object
#  9   diedCountryCode  27 non-null     object
#  10  diedCity         27 non-null     object
#  11  gender           60 non-null     object
#  12  prizes           60 non-null     object
#  13  knownName        59 non-null     object
# dtypes: object(14)
# memory usage: 7.0+ KB

# %%
female_df.bornCountry.value_counts()
# Out:
# USA                                          16
# France                                        5
# Poland                                        2
# Canada                                        2
# Italy                                         2
# Germany                                       2
# Northern Ireland                              2
# Liberia                                       2
# Sweden                                        2
# Australia                                     1
# British Mandate of Palestine (now Israel)     1
# Romania                                       1
# Yemen                                         1
# Pakistan                                      1
# Norway                                        1
# Kenya                                         1
# China                                         1
# Ukraine                                       1
# Iraq                                          1
# Persia (now Iran)                             1
# ...

# %%
female_df.diedCountry.value_counts()
# Out:
# USA                 11
# Sweden               3
# France               2
# United Kingdom       2
# Italy                2
# Austria              1
# Northern Ireland     1
# India                1
# Norway               1
# South Africa         1
# Poland               1
# Kenya                1
# Name: diedCountry, dtype: int64

# %% [markdown]
# #  Transformation 3: Extract award year from 'prizes' column.

# %%
api_nobel_df.prizes.dtype
# Out:
# dtype('O')

# %%
api_nobel_df['award_year'] = api_nobel_df['prizes'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)

# %%
move_decimal = api_nobel_df['award_year']/10

# %%
api_nobel_df['award_year'] = move_decimal.astype(int)

# %%
api_nobel_df['award_year']
# Out:
# 0      1901
# 1      1902
# 2      1902
# 3      1903
# 4      1903
#        ...
# 976    2022
# 977    2022
# 978    2022
# 979    2022
# 980    2022
# Name: award_year, Length: 981, dtype: int32

# %% [markdown]
# #  Transformation 4: Determine age at time of prize win.

# %%
female_df.prizes.head()
# Out:
# 5      [{'year': '1903', 'category': 'physics', 'shar...
# 77     [{'year': '1963', 'category': 'physics', 'shar...
# 189    [{'year': '1935', 'category': 'chemistry', 'sh...
# 225    [{'year': '1964', 'category': 'chemistry', 'sh...
# 338    [{'year': '1947', 'category': 'medicine', 'sha...
# Name: prizes, dtype: object

# %%
female_df['award_year'] = female_df['prizes'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14880\2650851957.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_df['award_year'] = female_df['prizes'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)

# %%
female_df[['born', 'award_year']]
# Out:
#            born  award_year
# 5    1867-11-07  1903419111
# 77   1906-06-28       19634
# 189  1897-09-12       19352
# 225  1910-05-12       19641
# 338  1896-08-15       19474
# 407  1921-07-19       19772
# 422  1902-06-16       19831
# 429  1909-04-22       19862
# 432  1918-01-23       19883
# 447  1942-10-20       19953
# 462  1843-06-09       19051
# 489  1860-09-06       19312
# 498  1867-01-08       19462
# 525  1943-05-22       19762
# 526  1944-01-27       19762
# 530  1910-08-26       19791
# 532  1902-01-31       19822
# 542  1945-06-19       19911
# 543  1959-01-09       19921
# 554  1950-10-09       19972
# 567  1858-11-20       19091
# 583  1871-09-27       19261
# 585  1882-05-20       19281
# 594  1892-06-26       19381
# 597  1889-04-07       19451
# 619  1891-12-10       19662
# 645  1923-11-20       19911
# 647  1931-02-18       19931
# 650  1923-07-02       19961
# 750  1947-06-21       20031
# 752  1947-01-29       20042
# 759  1946-10-20       20041
# ...

# %%
# Glean Marie Curie's award_year year
female_df['award_year'].replace(190341911, '1903')
# Out:
# 5      1903419111
# 77          19634
# 189         19352
# 225         19641
# 338         19474
# 407         19772
# 422         19831
# 429         19862
# 432         19883
# 447         19953
# 462         19051
# 489         19312
# 498         19462
# 525         19762
# 526         19762
# 530         19791
# 532         19822
# 542         19911
# 543         19921
# 554         19972
# 567         19091
# 583         19261
# 585         19281
# 594         19381
# 597         19451
# 619         19662
# 645         19911
# 647         19931
# 650         19961
# 750         20031
# 752         20042
# 759         20041
# 760         20041
# 791         20071
# 798         20084
# 809         20093
# 810         20093
# 817         20093
# 818         20091
# 820         20092
# 841         20113
# 842         20113
# 843         20113
# 864         20131
# 870         20144
# 880         20142
# 884         20152
# 890         20151
# 920         20184
# 921         20182
# ...

# %%
female_df['born'] = pd.to_datetime(female_df['born'], format='%Y-%m-%d', errors='coerce')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14880\739920948.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_df['born'] = pd.to_datetime(female_df['born'], format='%Y-%m-%d', errors='coerce')

# %%
female_df['born'].dtype
# Out:
# dtype('<M8[ns]')

# %%
female_df['award_year'] = pd.to_datetime(female_df['award_year'], format='%Y', errors='coerce')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14880\1495774267.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_df['award_year'] = pd.to_datetime(female_df['award_year'], format='%Y', errors='coerce')

# %%
female_df['award_year'].dtype
# Out:
# dtype('<M8[ns]')

# %%
# Create new column 'age_at_award' which displays Laureate's age at time of award.
# Convert days to years and remove decimals
import numpy as np
female_df['age_at_award'] = ((female_df['award_year'] - female_df['born']) / np.timedelta64(1, 'Y')).apply(np.floor)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14880\855340606.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_df['age_at_award'] = ((female_df['award_year'] - female_df['born']) / np.timedelta64(1, 'Y')).apply(np.floor)

# %%
female_df['age_at_award'].mean()
# Out:
# nan

# %%
female_df['died'] = pd.to_datetime(female_df['died'], format='%Y-%m-%d', errors='coerce')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14880\187489917.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_df['died'] = pd.to_datetime(female_df['died'], format='%Y-%m-%d', errors='coerce')

# %%
female_df['lifespan'] = ((female_df['died'] - female_df['born'])  / np.timedelta64(1, 'Y')).apply(np.floor)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14880\2165558311.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_df['lifespan'] = ((female_df['died'] - female_df['born'])  / np.timedelta64(1, 'Y')).apply(np.floor)

# %%
female_df['lifespan'].mean()
# Out:
# 78.85185185185185

# %% [markdown]
# #  Create 'age_at_award' column for api df

# %%
api_nobel_df['born'] = pd.to_datetime(api_nobel_df['born'], format='%Y-%m-%d', errors='coerce')

# %%
api_nobel_df['award_year'] = pd.to_datetime(api_nobel_df['award_year'], format='%Y', errors='coerce')

# %%
# Create new column 'age_at_award' which displays Laureate's age at time of award.
# Convert days to years and remove decimals
import numpy as np
api_nobel_df['age_at_award'] = ((api_nobel_df['award_year'] - api_nobel_df['born']) / np.timedelta64(1, 'Y')).apply(np.floor)

# %%
api_nobel_df['age_at_award'].mean()
# Out:
# 59.27056277056277

# %%
api_nobel_df['died'] = pd.to_datetime(api_nobel_df['died'], format='%Y-%m-%d', errors='coerce')

# %%
api_nobel_df['lifespan'] = ((api_nobel_df['died'] - api_nobel_df['born'])  / np.timedelta64(1, 'Y')).apply(np.floor)

# %%
api_nobel_df['lifespan'].mean()
# Out:
# 80.21779141104294

# %%
api_nobel_df.head()
# Out:
#   id       firstname    surname       born       died            bornCountry  \
# 0  1  Wilhelm Conrad    Röntgen 1845-03-27 1923-02-10  Prussia (now Germany)
# 1  2      Hendrik A.    Lorentz 1853-07-18 1928-02-04        the Netherlands
# 2  3          Pieter     Zeeman 1865-05-25 1943-10-09        the Netherlands
# 3  4           Henri  Becquerel 1852-12-15 1908-08-25                 France
# 4  5          Pierre      Curie 1859-05-15 1906-04-19                 France
#
#   bornCountryCode                bornCity      diedCountry diedCountryCode  \
# 0              DE  Lennep (now Remscheid)          Germany              DE
# 1              NL                  Arnhem  the Netherlands              NL
# 2              NL              Zonnemaire  the Netherlands              NL
# 3              FR                   Paris           France              FR
# 4              FR                   Paris           France              FR
#
# ...

# %% [markdown]
# #  Transformation 5. Create df with only necessary columns...the columns that will be merged upon and the columns with useful data.

# %%
api_nobel = api_nobel_df[['gender', 'knownName', 'age_at_award', 'lifespan']]

# %%
api_nobel.head(10)
# Out:
#    gender               knownName  age_at_award  lifespan
# 0    male  Wilhelm Conrad Röntgen          55.0      77.0
# 1    male      Hendrik A. Lorentz          48.0      74.0
# 2    male           Pieter Zeeman          36.0      78.0
# 3    male         Henri Becquerel          50.0      55.0
# 4    male            Pierre Curie          43.0      46.0
# 5  female             Marie Curie           NaN      66.0
# 6    male           Lord Rayleigh          61.0      76.0
# 7    male          Philipp Lenard          42.0      84.0
# 8    male            J.J. Thomson          49.0      83.0
# 9    male     Albert A. Michelson          54.0      78.0

# %% [markdown]
# # Milestone 4 Ethical Issues

# %% [markdown]
# #  The most critical ethical issue in the data is the small sample size of female Laureates- 60 observations. One can unequivocally state that males have won Nobel prizes at a disproportional rate relative to females. One must take special care when studying the demographics of female Laureates and generalizing to the female population at large. This is especially true when one looks through a granular prism at subsets of female Laureates by country and by category of prize. After USA(16) and France(5), no ‘bornCountry’ has more than two female winners. Another important issue when grouping Laureates by country is that many of the United States winners were immigrants. Immigrants have won a much greater percentage of prizes than their percentage in the population at large would suggest. We do not have data in these datasets that inform us what effect birth country has on lifespan relative to the country where one lives. For example, a new study states that black women have double the maternal mortality rates as white women(https://news.vanderbilt.edu/2022/04/18/new-study-black-women-face-higher-maternal-mortality-rates-than-previously-determined/). This is after controlling for other factors. The data shows that a wealthy black woman is still so disadvantaged. Our data does not trace race, ethnicity, or even social class, which are most certainly drivers of lifespan. Another concern with the API dataset is the great number of 0 values in the ‘died’ column. I chose not to impute any values because every option would skew the true data. Any skew would have a detrimental effect on the analysis. I anticipate merging the datasets and gleaning true values for the missing ones in the API file.

# %% [markdown]
# #  Project Milestone 5 Merging and Storing the Data

# %% [markdown]
# #  Load flat file into SQLite3 db and create db

# %%
import sqlite3
conn = sqlite3.connect('term_project_db.sqlite')
flat_file_df.to_sql('nobel_flat', conn, if_exists='replace', index=False)
conn.close()

# %%
# Check if flat table in db
conn = sqlite3.connect('term_project_db.sqlite')
wiki_df = pd.read_sql_query('SELECT * FROM nobel_flat', conn)
conn.close()
wiki_df.head()
# Out:
#    awardYear           category portion  prizeAmountAdjusted  \
# 0       2001  Economic Sciences     1/3             12295082
# 1       1975            Physics     1/3              3404179
# 2       2004          Chemistry     1/3             11762861
# 3       1982          Chemistry       1              3102518
# 4       1979            Physics     1/3              2988048
#
#            knownName gender  years_lived
# 0  A. Michael Spence   male          NaN
# 1       Aage N. Bohr   male         87.0
# 2  Aaron Ciechanover   male          NaN
# 3         Aaron Klug   male         92.0
# 4        Abdus Salam   male         70.0

# %% [markdown]
# #  Load webpage file into db

# %%
conn = sqlite3.connect('term_project_db.sqlite')
table_transposed_df.to_sql('nobel_wiki', conn, if_exists='replace', index=False)
conn.close()

# %%
# Check if wiki table in db
conn = sqlite3.connect('term_project_db.sqlite')
wiki_df = pd.read_sql_query('SELECT * FROM nobel_wiki', conn)
conn.close()
wiki_df.head()
# Out:
#   Time Periods  Afghanistan *  Albania *  Algeria *  Angola *  \
# 0    1950–1955          28.61      55.26      42.89     31.39
# 1    1955–1960          31.12      59.31      45.00     32.54
# 2    1960–1965          33.41      64.85      47.29     34.09
# 3    1965–1970          35.58      66.24      49.47     36.04
# 4    1970–1975          37.83      67.69      51.48     38.05
#
#    Antigua and Barbuda  Argentina *  Armenia *  Aruba (Netherlands)  \
# 0                58.51        62.57      62.82                60.44
# 1                61.03        64.58      64.92                64.36
# 2                63.18        65.31      67.04                66.58
# 3                65.05        65.84      69.18                68.22
# 4                66.71        67.28      70.75                70.05
#
#    Australia *  Austria *  Azerbaijan *  Bahamas  Bahrain *  Bangladesh *  \
# 0        69.37      66.54         58.43    60.02      42.98         40.67
# ...

# %% [markdown]
# #  Load API File into db

# %%
conn = sqlite3.connect('term_project_db.sqlite')
api_nobel.to_sql('nobel_api', conn, if_exists='replace',index=False)
conn.close()

# %%
# Check if api table in db
conn = sqlite3.connect('term_project_db.sqlite')
api_df = pd.read_sql_query('SELECT * FROM nobel_api', conn)
conn.close()
api_df.head()
# Out:
#   gender               knownName  age_at_award  lifespan
# 0   male  Wilhelm Conrad Röntgen          55.0      77.0
# 1   male      Hendrik A. Lorentz          48.0      74.0
# 2   male           Pieter Zeeman          36.0      78.0
# 3   male         Henri Becquerel          50.0      55.0
# 4   male            Pierre Curie          43.0      46.0

# %%
import sqlite3
conn = sqlite3.connect('term_project_db.sqlite')
cursor = conn.cursor()
sql = '''Select * 
FROM nobel_flat 
LEFT JOIN nobel_wiki 
ON nobel_flat.knownName = nobel_wiki.knownName 
LEFT JOIN nobel_api 
ON nobel_wiki.knownName = nobel_api.knownName 
LIMIT 4;'''
cursor.execute(sql)
result = cursor.fetchall()
for row in result:
    print(row)


# Closing the connection
conn.close()
# Out:
# (2001, 'Economic Sciences', '1/3', 12295082, 'A. Michael Spence', 'male', None, '1950–1955', 28.61, 55.26, 42.89, 31.39, 58.51, 62.57, 62.82, 60.44, 69.37, 66.54, 58.43, 60.02, 42.98, 40.67, 57.22, 60.71, 67.81, 55.92, 33.72, 32.26, 40.02, 53.67, 47.67, 50.83, 58.28, 62.33, 30.94, 39.03, 40.32, 38.54, 69.05, 48.06, 33.44, 36.06, 69.22, 54.64, 43.83, 50.67, 38.72, 56.0, 61.26, 59.44, 60.65, 66.73, 66.86, 39.06, 71.06, 41.04, 45.97, 48.65, 41.14, 44.25, 34.48, 34.08, 61.77, 41.44, 34.08, 54.58, 52.21, 66.4, 67.05, 53.33, 48.94, 37.0, 30.24, 60.65, 67.52, 42.17, 65.75, 56.34, 53.32, 57.2, 42.92, 33.07, 35.88, 58.83, 37.48, 41.8, 63.1, 64.01, 72.23, 36.62, 43.49, 40.58, 37.93, 66.9, 68.88, 66.52, 32.14, 58.61, 62.8, 46.51, 55.06, 42.3, 46.38, 53.55, 52.83, 40.93, 62.4, 60.46, 42.15, 33.13, 60.83, 65.96, 36.67, 61.0, 54.9, 36.32, 36.26, 54.8, 34.47, 26.96, 66.11, 55.59, 38.59, 50.19, 47.2, 50.72, 59.04, 43.18, 59.77, 45.67, 31.29, 44.2, 41.75, 34.01, 71.93, 50.74, 69.76, 42.3, 34.5, 33.81
# ...

# %% [markdown]
# #  Merge dfs to create visualizations

# %%
flat_file_df['avg_lifespan_1950'] = first_period_US
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14880\2527495610.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   flat_file_df['avg_lifespan_1950'] = first_period_US

# %%
flat_file_df.head()
# Out:
#    awardYear           category portion  prizeAmountAdjusted  \
# 0       2001  Economic Sciences     1/3             12295082
# 1       1975            Physics     1/3              3404179
# 2       2004          Chemistry     1/3             11762861
# 3       1982          Chemistry       1              3102518
# 4       1979            Physics     1/3              2988048
#
#            knownName gender  years_lived  avg_lifespan_1950
# 0  A. Michael Spence   male          NaN              68.71
# 1       Aage N. Bohr   male         87.0              68.71
# 2  Aaron Ciechanover   male          NaN              68.71
# 3         Aaron Klug   male         92.0              68.71
# 4        Abdus Salam   male         70.0              68.71

# %%
merged_dfs = pd.merge(flat_file_df, api_df, on=['knownName', 'gender'])

# %%
merged_dfs.head()
# Out:
#    awardYear           category portion  prizeAmountAdjusted  \
# 0       2001  Economic Sciences     1/3             12295082
# 1       1975            Physics     1/3              3404179
# 2       2004          Chemistry     1/3             11762861
# 3       1982          Chemistry       1              3102518
# 4       1979            Physics     1/3              2988048
#
#            knownName gender  years_lived  avg_lifespan_1950  age_at_award  \
# 0  A. Michael Spence   male          NaN              68.71           NaN
# 1       Aage N. Bohr   male         87.0              68.71          52.0
# 2  Aaron Ciechanover   male          NaN              68.71          56.0
# 3         Aaron Klug   male         92.0              68.71          55.0
# 4        Abdus Salam   male         70.0              68.71          52.0
#
#    lifespan
# 0       NaN
# 1      87.0
# 2       NaN
# 3      92.0
# 4      70.0

# %%
merged_dfs.category.value_counts()
# Out:
# Physiology or Medicine    214
# Physics                   212
# Chemistry                 183
# Literature                115
# Peace                      98
# Economic Sciences          84
# Name: category, dtype: int64

# %%
merged_dfs.portion.value_counts()
# Out:
# 1      324
# 1/2    304
# 1/3    211
# 1/4     67
# Name: portion, dtype: int64

# %%
merged_dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 906 entries, 0 to 905
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   awardYear            906 non-null    int64
#  1   category             906 non-null    object
#  2   portion              906 non-null    object
#  3   prizeAmountAdjusted  906 non-null    int64
#  4   knownName            906 non-null    object
#  5   gender               906 non-null    object
#  6   years_lived          623 non-null    float64
#  7   avg_lifespan_1950    906 non-null    float64
#  8   age_at_award         880 non-null    float64
#  9   lifespan             650 non-null    float64
# dtypes: float64(4), int64(2), object(4)
# memory usage: 77.9+ KB

# %%
merged_dfs.isnull().sum()
# Out:
# awardYear                0
# category                 0
# portion                  0
# prizeAmountAdjusted      0
# knownName                0
# gender                   0
# years_lived            283
# avg_lifespan_1950        0
# age_at_award            26
# lifespan               256
# dtype: int64

# %%
merged_dfs.describe()
# Out:
#          awardYear  prizeAmountAdjusted  years_lived  avg_lifespan_1950  \
# count   906.000000         9.060000e+02   623.000000       9.060000e+02
# mean   1970.693157         6.124010e+06    79.860353       6.871000e+01
# std      33.600524         3.274569e+06    10.776512       7.535913e-13
# min    1901.000000         2.377268e+06    39.000000       6.871000e+01
# 25%    1947.000000         3.052326e+06    73.000000       6.871000e+01
# 50%    1976.000000         4.913422e+06    81.000000       6.871000e+01
# 75%    1999.750000         9.044276e+06    88.000000       6.871000e+01
# max    2019.000000         1.229508e+07   103.000000       6.871000e+01
#
#        age_at_award    lifespan
# count    880.000000  650.000000
# mean      58.860227   80.226154
# std       12.562010   10.780894
# min       16.000000   39.000000
# 25%       49.750000   74.000000
# 50%       59.000000   82.000000
# 75%       68.000000   88.000000
# max       95.000000  103.000000

# %%
nobel_male = merged_dfs[merged_dfs['gender'] == 'male']

# %%
nobel_male.head()
# Out:
#    awardYear           category portion  prizeAmountAdjusted  \
# 0       2001  Economic Sciences     1/3             12295082
# 1       1975            Physics     1/3              3404179
# 2       2004          Chemistry     1/3             11762861
# 3       1982          Chemistry       1              3102518
# 4       1979            Physics     1/3              2988048
#
#            knownName gender  years_lived  avg_lifespan_1950  age_at_award  \
# 0  A. Michael Spence   male          NaN              68.71           NaN
# 1       Aage N. Bohr   male         87.0              68.71          52.0
# 2  Aaron Ciechanover   male          NaN              68.71          56.0
# 3         Aaron Klug   male         92.0              68.71          55.0
# 4        Abdus Salam   male         70.0              68.71          52.0
#
#    lifespan
# 0       NaN
# 1      87.0
# 2       NaN
# 3      92.0
# 4      70.0

# %%
nobel_female = merged_dfs[merged_dfs['gender'] == 'female']

# %%
nobel_female.head()
# Out:
#     awardYear                category portion  prizeAmountAdjusted  \
# 7        2009               Chemistry     1/3             10958504
# 39       2013              Literature       1              8365867
# 43       1982                   Peace     1/2              3102518
# 78       1983  Physiology or Medicine       1              3715324
# 90       1905                   Peace       1              7615202
#
#              knownName  gender  years_lived  avg_lifespan_1950  age_at_award  \
# 7        Ada E. Yonath  female          NaN              68.71          69.0
# 39         Alice Munro  female          NaN              68.71          81.0
# 43         Alva Myrdal  female         84.0              68.71          79.0
# 78  Barbara McClintock  female         90.0              68.71          80.0
# 90  Bertha von Suttner  female         71.0              68.71          61.0
#
#     lifespan
# 7        NaN
# 39       NaN
# 43      84.0
# 78      90.0
# 90      71.0

# %%
nobel_male.describe()
# Out:
#          awardYear  prizeAmountAdjusted  years_lived  avg_lifespan_1950  \
# count   855.000000         8.550000e+02   596.000000       8.550000e+02
# mean   1969.992982         6.040718e+06    79.941275       6.871000e+01
# std      33.406866         3.262114e+06    10.737740       7.393970e-13
# min    1901.000000         2.377268e+06    39.000000       6.871000e+01
# 25%    1946.000000         3.050198e+06    74.000000       6.871000e+01
# 50%    1975.000000         4.907955e+06    82.000000       6.871000e+01
# 75%    1998.000000         9.044276e+06    88.000000       6.871000e+01
# max    2019.000000         1.229508e+07   102.000000       6.871000e+01
#
#        age_at_award    lifespan
# count    832.000000  623.000000
# mean      58.965144   80.319422
# std       12.389293   10.740990
# min       24.000000   39.000000
# 25%       49.750000   74.000000
# 50%       59.000000   82.000000
# 75%       68.000000   88.000000
# max       95.000000  102.000000

# %%
nobel_female.describe()
# Out:
#          awardYear  prizeAmountAdjusted  years_lived  avg_lifespan_1950  \
# count    51.000000         5.100000e+01    27.000000       5.100000e+01
# mean   1982.431373         7.520388e+06    78.074074       6.871000e+01
# std      34.989858         3.196923e+06    11.671550       2.870452e-14
# min    1903.000000         2.499993e+06    58.000000       6.871000e+01
# 25%    1963.500000         4.278428e+06    67.000000       6.871000e+01
# 50%    1995.000000         8.384572e+06    78.000000       6.871000e+01
# 75%    2009.000000         1.054556e+07    88.000000       6.871000e+01
# max    2019.000000         1.180730e+07   103.000000       6.871000e+01
#
#        age_at_award    lifespan
# count     48.000000   27.000000
# mean      57.041667   78.074074
# std       15.290045   11.671550
# min       16.000000   58.000000
# 25%       49.250000   67.000000
# 50%       56.000000   78.000000
# 75%       69.000000   88.000000
# max       87.000000  103.000000

# %%
import matplotlib.pyplot as plt
x = merged_dfs['awardYear']
y = merged_dfs['prizeAmountAdjusted']
plt.scatter(x, y)
plt.show()

# %% [markdown]
# #  Visualization 1: Compare adjusted price amount to year, by gender

# %%
fig = plt.figure()
 
fig.set_size_inches(10, 10)
x = nobel_male['awardYear']
y = nobel_male['prizeAmountAdjusted']
plt.scatter(x, y, color = '#88c999')

x = nobel_female['awardYear']
y = nobel_female['prizeAmountAdjusted']
plt.scatter(x, y, color = 'hotpink')
plt.xlabel('Award Year', fontsize=20)
plt.ylabel('Prize Amount in dollars Adjusted', fontsize=20)
plt.title('Compare Prize Winnings by Year', fontsize=25)
plt.legend(["Male", "Female"], fontsize=20, loc ="lower right")

plt.show()

# %% [markdown]
# #  Visualization 2: Compare Laureates' Lifespan to Population at Large

# %%
fig = plt.figure()
 
fig.set_size_inches(12, 12)
x = np.arange(906)
y = merged_dfs.avg_lifespan_1950
plt.plot(x,y, linewidth=7)



x = np.arange(906)
y = merged_dfs.years_lived
plt.plot(x,y)
plt.xlabel('Count of Awards', fontsize=20)
plt.ylabel('Age in Years', fontsize=20)
plt.title('Compare Laureates Age to Average Lifespan', fontsize=25)
plt.legend(["Average Lifespan", "Laureates' Lifespan"], fontsize=20, loc ="lower right")
plt.show()

# %% [markdown]
# #  Laureates Outlived Average Person

# %% [markdown]
# #  Visualization 3: Count of Laureates who shared award

# %%
merged_dfs.portion.value_counts()
# Out:
# 1      324
# 1/2    304
# 1/3    211
# 1/4     67
# Name: portion, dtype: int64

# %%
fig = plt.figure()
 
fig.set_size_inches(12, 12)
y = np.array([324, 304, 211, 67])
mylabels = ["1", "1/2", "1/3", "1/4"]
myexplode = [0.2, 0, 0, 0]
plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.title('Shared Prize', fontsize=35)
plt.legend(title = "Prize Portion:", fontsize=20, loc ="lower right")
plt.show()

# %% [markdown]
# #  Visualization 4

# %%
fig = plt.figure()
 
fig.set_size_inches(10, 10)
x = nobel_male['awardYear']
y = nobel_male['age_at_award']
plt.scatter(x, y,  c ="pink",
            linewidths = 2,
            marker ="s",
            edgecolor ="green",
            s = 50) 

x = nobel_female['awardYear']
y = nobel_female['age_at_award']
plt.scatter(x, y, c ="yellow",
            linewidths = 2,
            marker ="^",
            edgecolor ="red",
            s = 200) 
plt.xlabel('Award Year', fontsize=20)
plt.ylabel('Age at Time of Winning', fontsize=20)
plt.title('Compare Age at Time of Award by Year', fontsize=25)
plt.legend(["Male", "Female"], fontsize=20, loc ="lower right")

plt.show()

# %% [markdown]
# #  There exists a slight upward trend where one would have expected a strong upward trend in age at time of winning, relative to the strong upward trend in life expectancy from the late 1800s through 2020.

# %% [markdown]
# #  Visualization 5:

# %%
'''albg = new_flat_df[['categoryFullName', 'gender', 'years_lived']]
albg.groupby('categoryFullName').mean().plot(kind='bar')'''
# Out:
# "albg = new_flat_df[['categoryFullName', 'gender', 'years_lived']]\nalbg.groupby('categoryFullName').mean().plot(kind='bar')"

# %%
'''gendercount_by_category.plot(kind='bar')
plt.xlabel('Number of Laureates')
plt.show()'''
# Out:
# "gendercount_by_category.plot(kind='bar')\nplt.xlabel('Number of Laureates')\nplt.show()"

# %% [markdown]
# #  Visualization 5 Graph average lifespans of Laureates by category/gender

# %%
fig = plt.figure()
sns.set(font_scale=4)
 
fig.set_size_inches(30, 10)
sns.barplot(x='categoryFullName', y='years_lived', hue='gender', data=new_flat_df, palette = "Blues")
plt.title('Average Lifespan of Laureates by Category/Gender')
plt.xticks(rotation=80)
plt.show()

# %% [markdown]
# #  Milestone 5

# %% [markdown]
# # Female Nobel Laureates
#
# There is a plethora of data about Nobel Laureates, easily and freely accessible in csv file, webpage, and API formats.  The data is not cleaned and some wrangling must be performed in order to make it usable. There is a significant number of null values throughout the data. Therefore, discounting the nulls is not an option for doing so would skew true results. The best plan to deal with the null values is to complement the datasets with each other. I used this same strategy to deal with differences in string names.  Fuzzy Matching was a boon in comparing name columns both within a df and between dfs.
#
# The most impressive piece of data is the Laureate discrepancy between genders...869 to 54. Females comprise only slightly more than six percent of Laureates. Females performed best in the ‘liberal arts’ prizes of Peace and Literature, where they garnered 17 out of 107 and 15 out of 116 prizes respectively. Even in Physiology and Medicine where women have been better presented in the world at large, females have fared poorly, winning only 12 out of 219 awards. In Chemistry women have won 5 out of 184 times, in Physics 3 out of 213, and in Economics 2 out of 84 times. These discrepancies are glaring and clearly statistically significant. This trend holds true through all categories. There exists too great of a difference between males and females to entertain a possibility that these results are due to chance.
#
# Less apparent are any age correlations with Nobel awards. It is a veritable impossibility to get an accurate baseline for mean lifespan. Statistics show an average expected lifetime for a person born during a specific year. One must note that this average lifespan for a human born during a certain year assumes a flat line of average lifespans throughout the expected decades of his life. Needless to say, lifespan averages change over time. For instance, until the Covid-19 pandemic lifespans had been growing in the United States of America. In addition it is an open ethical question if appropriate to compare female U.S. Laureates to the average U.S. lifespan. There is a disproportionate number of Nobel Laureates for the U.S. who hail from other countries and who are immigrants. Should they be qualified as belonging to the country which they were born in, won the award in, lived longest in, or died in? One must include U.S.A. female laureates in any study because no other country boasted more than five female winners. No country after U.S.A. and France boasts more than 2 female Laureates. The statistics show no great differences between male and female Laureates, and no great difference between female Laureates and the population at large. There does not exist a large enough sample of female Laureates of any category, whether it be country, year, or award category to extrapolate to the population at large. The data shows nothing about the demographics of the winners like social caste or wealth. It would therefore be ethically inappropriate to extrapolate anything about lifespans of academically and intellectually successful women from this paltry data sample.
#
# This EDA is in accordance with the European General Data Protection Regulation, including its most recent regulations(https://gdpr-info.eu/art-5-gdpr/). Ethical accountability belongs to me. I am responsible for ensuring that all ethical implications are considered. The data used is public and there are no privacy issues to contend with presently, and no privacy issues for downstream users of the data. If one were to strive to ensure anonymity, he could anonymize the data. The names are not necessary for any results or conclusions. Names were used to merge the data correctly. All of the data sources were open. Careful attention was paid to any biases in modeling and I attempted all reasonable modeling. There is transparency in the EDA which ensures reproducibility and proof of an objective point of view in assessing the data. I strived to represent the data conclusions precisely and clearly to protect against someone misconstruing it.
